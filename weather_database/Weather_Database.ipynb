# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 730

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | aklavik
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | presque isle
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | manaus
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | lolua
# City not found. Skipping
# Processing Record 10 of Set 1 | kashin
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | qui nhon
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | margate
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | codrington
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | san quintin
# Processing Record 25 of Set 1 | anuradhapura
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | sao filipe
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | paramonga
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | matagami
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | sao joao da barra
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | dipkarpaz
# City not found. Skipping
# Processing Record 37 of Set 1 | marienburg
# Processing Record 38 of Set 1 | wana
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | katima mulilo
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | vila franca do campo
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | evanton
# Processing Record 48 of Set 1 | belmonte
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | san blas
# Processing Record 2 of Set 2 | fairbanks
# Processing Record 3 of Set 2 | mercedes
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | mutata
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | maldonado
# Processing Record 9 of Set 2 | kalmunai
# Processing Record 10 of Set 2 | kavaratti
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | hervey bay
# Processing Record 14 of Set 2 | san ramon
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | taburi
# City not found. Skipping
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | shihezi
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | takoradi
# Processing Record 24 of Set 2 | itacurubi del rosario
# Processing Record 25 of Set 2 | tomaszow mazowiecki
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | mudu
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | padang
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 33 of Set 2 | okha
# Processing Record 34 of Set 2 | sinnamary
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | rocha
# Processing Record 37 of Set 2 | broken hill
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | geraldton
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | yashkul
# Processing Record 42 of Set 2 | torata
# Processing Record 43 of Set 2 | binzhou
# Processing Record 44 of Set 2 | ahuimanu
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping
# Processing Record 46 of Set 2 | moussoro
# Processing Record 47 of Set 2 | williston
# Processing Record 48 of Set 2 | suslovo
# Processing Record 49 of Set 2 | bud
# Processing Record 50 of Set 2 | kaitangata
# Processing Record 1 of Set 3 | roebourne
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | tautira
# Processing Record 4 of Set 3 | pinawa
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | coquimbo
# Processing Record 8 of Set 3 | galdar
# Processing Record 9 of Set 3 | zaraza
# Processing Record 10 of Set 3 | buin
# Processing Record 11 of Set 3 | norman wells
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | laramie
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping
# Processing Record 15 of Set 3 | mastic beach
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | haapsalu
# Processing Record 18 of Set 3 | qujing
# Processing Record 19 of Set 3 | boa vista
# Processing Record 20 of Set 3 | port augusta
# Processing Record 21 of Set 3 | monterey
# Processing Record 22 of Set 3 | vaitupu
# City not found. Skipping
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | whitehorse
# Processing Record 25 of Set 3 | ankazobe
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | maxixe
# Processing Record 28 of Set 3 | alofi
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | adrar
# Processing Record 31 of Set 3 | kulhudhuffushi
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | mitsamiouli
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | olafsvik
# Processing Record 36 of Set 3 | nara
# Processing Record 37 of Set 3 | berlevag
# Processing Record 38 of Set 3 | amapa
# Processing Record 39 of Set 3 | guru har sahai
# Processing Record 40 of Set 3 | okato
# Processing Record 41 of Set 3 | hualmay
# Processing Record 42 of Set 3 | flinders
# Processing Record 43 of Set 3 | embrach
# Processing Record 44 of Set 3 | ciras
# City not found. Skipping
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping
# Processing Record 46 of Set 3 | asfi
# Processing Record 47 of Set 3 | vila velha
# Processing Record 48 of Set 3 | govindgarh
# Processing Record 49 of Set 3 | motygino
# Processing Record 50 of Set 3 | hot springs
# Processing Record 1 of Set 4 | hilo
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping
# Processing Record 3 of Set 4 | halalo
# City not found. Skipping
# Processing Record 4 of Set 4 | pringsewu
# Processing Record 5 of Set 4 | taolanaro
# City not found. Skipping
# Processing Record 6 of Set 4 | ust-omchug
# Processing Record 7 of Set 4 | blackpool
# Processing Record 8 of Set 4 | dagda
# Processing Record 9 of Set 4 | kedrovyy
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | batemans bay
# Processing Record 12 of Set 4 | krasnyy chikoy
# Processing Record 13 of Set 4 | morant bay
# Processing Record 14 of Set 4 | omboue
# Processing Record 15 of Set 4 | tura
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | makakilo city
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping
# Processing Record 19 of Set 4 | ewa beach
# Processing Record 20 of Set 4 | sunggal
# Processing Record 21 of Set 4 | beyneu
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | omsukchan
# Processing Record 25 of Set 4 | malanje
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | kapaa
# Processing Record 28 of Set 4 | mount isa
# Processing Record 29 of Set 4 | de aar
# Processing Record 30 of Set 4 | luanda
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping
# Processing Record 32 of Set 4 | gizo
# Processing Record 33 of Set 4 | mayumba
# Processing Record 34 of Set 4 | baruun-urt
# Processing Record 35 of Set 4 | mumford
# Processing Record 36 of Set 4 | sola
# Processing Record 37 of Set 4 | lata
# Processing Record 38 of Set 4 | jha jha
# Processing Record 39 of Set 4 | araripina
# Processing Record 40 of Set 4 | monteagudo
# Processing Record 41 of Set 4 | talcahuano
# Processing Record 42 of Set 4 | kupang
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | buraydah
# Processing Record 45 of Set 4 | viedma
# Processing Record 46 of Set 4 | hammerfest
# Processing Record 47 of Set 4 | elesbao veloso
# Processing Record 48 of Set 4 | bogorodskoye
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping
# Processing Record 50 of Set 4 | conde
# Processing Record 1 of Set 5 | farah
# Processing Record 2 of Set 5 | ca mau
# Processing Record 3 of Set 5 | beira
# Processing Record 4 of Set 5 | riaba
# City not found. Skipping
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | kaoma
# Processing Record 7 of Set 5 | pokhara
# Processing Record 8 of Set 5 | urengoy
# Processing Record 9 of Set 5 | palabuhanratu
# City not found. Skipping
# Processing Record 10 of Set 5 | pevek
# Processing Record 11 of Set 5 | deputatskiy
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping
# Processing Record 13 of Set 5 | turayf
# Processing Record 14 of Set 5 | alice springs
# Processing Record 15 of Set 5 | dawlatabad
# Processing Record 16 of Set 5 | pacific grove
# Processing Record 17 of Set 5 | cherskiy
# Processing Record 18 of Set 5 | azul
# Processing Record 19 of Set 5 | altay
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | palmas
# Processing Record 22 of Set 5 | nantucket
# Processing Record 23 of Set 5 | paka
# Processing Record 24 of Set 5 | yermakovskoye
# Processing Record 25 of Set 5 | lavrentiya
# Processing Record 26 of Set 5 | sao geraldo do araguaia
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | salcininkai
# Processing Record 29 of Set 5 | wilmington
# Processing Record 30 of Set 5 | dali
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping
# Processing Record 32 of Set 5 | aloleng
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | aleksandrovskiy zavod
# Processing Record 35 of Set 5 | atengo
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | coahuayana
# Processing Record 38 of Set 5 | visby
# Processing Record 39 of Set 5 | pali
# Processing Record 40 of Set 5 | portland
# Processing Record 41 of Set 5 | gat
# Processing Record 42 of Set 5 | timra
# Processing Record 43 of Set 5 | ixtapa
# Processing Record 44 of Set 5 | henties bay
# Processing Record 45 of Set 5 | talnakh
# Processing Record 46 of Set 5 | lubango
# Processing Record 47 of Set 5 | butaritari
# Processing Record 48 of Set 5 | east london
# Processing Record 49 of Set 5 | itaituba
# Processing Record 50 of Set 5 | bonavista
# Processing Record 1 of Set 6 | crotone
# Processing Record 2 of Set 6 | funadhoo
# Processing Record 3 of Set 6 | dunedin
# Processing Record 4 of Set 6 | bhatkal
# Processing Record 5 of Set 6 | libertador general san martin
# Processing Record 6 of Set 6 | green river
# Processing Record 7 of Set 6 | meyungs
# City not found. Skipping
# Processing Record 8 of Set 6 | vilhena
# Processing Record 9 of Set 6 | wulanhaote
# City not found. Skipping
# Processing Record 10 of Set 6 | hovd
# Processing Record 11 of Set 6 | phalaborwa
# Processing Record 12 of Set 6 | gilgit
# Processing Record 13 of Set 6 | faya
# Processing Record 14 of Set 6 | kibala
# Processing Record 15 of Set 6 | lorengau
# Processing Record 16 of Set 6 | sisimiut
# Processing Record 17 of Set 6 | gardan diwal
# City not found. Skipping
# Processing Record 18 of Set 6 | tasiilaq
# Processing Record 19 of Set 6 | ocseny
# Processing Record 20 of Set 6 | pierre
# Processing Record 21 of Set 6 | tottori
# Processing Record 22 of Set 6 | paamiut
# Processing Record 23 of Set 6 | ruteng
# Processing Record 24 of Set 6 | klaksvik
# Processing Record 25 of Set 6 | adre
# Processing Record 26 of Set 6 | havre-saint-pierre
# Processing Record 27 of Set 6 | egvekinot
# Processing Record 28 of Set 6 | eichstatt
# Processing Record 29 of Set 6 | puerto colombia
# Processing Record 30 of Set 6 | louisbourg
# City not found. Skipping
# Processing Record 31 of Set 6 | vysokogornyy
# Processing Record 32 of Set 6 | xingyi
# Processing Record 33 of Set 6 | karaul
# City not found. Skipping
# Processing Record 34 of Set 6 | sangod
# Processing Record 35 of Set 6 | silver city
# Processing Record 36 of Set 6 | brookings
# Processing Record 37 of Set 6 | chuy
# Processing Record 38 of Set 6 | ndende
# Processing Record 39 of Set 6 | ngukurr
# City not found. Skipping
# Processing Record 40 of Set 6 | ayios matthaios
# City not found. Skipping
# Processing Record 41 of Set 6 | bilibino
# Processing Record 42 of Set 6 | laurel
# Processing Record 43 of Set 6 | jalu
# Processing Record 44 of Set 6 | dukat
# Processing Record 45 of Set 6 | taoudenni
# Processing Record 46 of Set 6 | mindelo
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | zhezkazgan
# Processing Record 49 of Set 6 | caiaponia
# Processing Record 50 of Set 6 | wanning
# Processing Record 1 of Set 7 | mahebourg
# Processing Record 2 of Set 7 | bardiyah
# Processing Record 3 of Set 7 | bilma
# Processing Record 4 of Set 7 | najran
# Processing Record 5 of Set 7 | bridlington
# Processing Record 6 of Set 7 | loandjili
# Processing Record 7 of Set 7 | lanzhou
# Processing Record 8 of Set 7 | naze
# Processing Record 9 of Set 7 | praya
# Processing Record 10 of Set 7 | amahai
# Processing Record 11 of Set 7 | ushtobe
# Processing Record 12 of Set 7 | marv dasht
# City not found. Skipping
# Processing Record 13 of Set 7 | loukhi
# Processing Record 14 of Set 7 | ternate
# Processing Record 15 of Set 7 | ponta do sol
# Processing Record 16 of Set 7 | pingliang
# Processing Record 17 of Set 7 | mogadishu
# Processing Record 18 of Set 7 | saint george
# Processing Record 19 of Set 7 | bethel
# Processing Record 20 of Set 7 | naryan-mar
# Processing Record 21 of Set 7 | tokomaru
# Processing Record 22 of Set 7 | alcacer do sal
# Processing Record 23 of Set 7 | saryshagan
# City not found. Skipping
# Processing Record 24 of Set 7 | fare
# Processing Record 25 of Set 7 | airai
# Processing Record 26 of Set 7 | vostok
# Processing Record 27 of Set 7 | araouane
# Processing Record 28 of Set 7 | ngorongoro
# Processing Record 29 of Set 7 | mecca
# Processing Record 30 of Set 7 | togur
# Processing Record 31 of Set 7 | cayenne
# Processing Record 32 of Set 7 | ambon
# Processing Record 33 of Set 7 | husavik
# Processing Record 34 of Set 7 | abiy adi
# City not found. Skipping
# Processing Record 35 of Set 7 | sorland
# Processing Record 36 of Set 7 | nome
# Processing Record 37 of Set 7 | moosomin
# Processing Record 38 of Set 7 | grand gaube
# Processing Record 39 of Set 7 | boali
# Processing Record 40 of Set 7 | amboasary
# Processing Record 41 of Set 7 | labuhan
# Processing Record 42 of Set 7 | ahipara
# Processing Record 43 of Set 7 | la brea
# Processing Record 44 of Set 7 | san luis
# Processing Record 45 of Set 7 | mao
# Processing Record 46 of Set 7 | namibe
# Processing Record 47 of Set 7 | constantine
# Processing Record 48 of Set 7 | bethanien
# Processing Record 49 of Set 7 | dzaoudzi
# Processing Record 50 of Set 7 | alto araguaia
# Processing Record 1 of Set 8 | axim
# Processing Record 2 of Set 8 | akyab
# Processing Record 3 of Set 8 | karratha
# Processing Record 4 of Set 8 | sumenep
# Processing Record 5 of Set 8 | tolaga bay
# Processing Record 6 of Set 8 | port-gentil
# Processing Record 7 of Set 8 | matara
# Processing Record 8 of Set 8 | pentecoste
# Processing Record 9 of Set 8 | thompson
# Processing Record 10 of Set 8 | okhotsk
# Processing Record 11 of Set 8 | sorata
# Processing Record 12 of Set 8 | robertsport
# Processing Record 13 of Set 8 | palmer
# Processing Record 14 of Set 8 | neiafu
# Processing Record 15 of Set 8 | bushehr
# Processing Record 16 of Set 8 | tuatapere
# Processing Record 17 of Set 8 | dakar
# Processing Record 18 of Set 8 | vanimo
# Processing Record 19 of Set 8 | iqaluit
# Processing Record 20 of Set 8 | dolinsk
# Processing Record 21 of Set 8 | kamina
# Processing Record 22 of Set 8 | grimshaw
# Processing Record 23 of Set 8 | korla
# Processing Record 24 of Set 8 | gushikawa
# Processing Record 25 of Set 8 | upington
# Processing Record 26 of Set 8 | muzaffargarh
# Processing Record 27 of Set 8 | caravelas
# Processing Record 28 of Set 8 | saint-augustin
# Processing Record 29 of Set 8 | grindavik
# Processing Record 30 of Set 8 | moose factory
# Processing Record 31 of Set 8 | matamoros
# Processing Record 32 of Set 8 | mayo
# Processing Record 33 of Set 8 | toguchin
# Processing Record 34 of Set 8 | chicama
# Processing Record 35 of Set 8 | mitu
# Processing Record 36 of Set 8 | nakhon phanom
# Processing Record 37 of Set 8 | antofagasta
# Processing Record 38 of Set 8 | marrakesh
# Processing Record 39 of Set 8 | haines junction
# Processing Record 40 of Set 8 | esperance
# Processing Record 41 of Set 8 | charleston
# Processing Record 42 of Set 8 | turukhansk
# Processing Record 43 of Set 8 | ha giang
# Processing Record 44 of Set 8 | mapiripan
# Processing Record 45 of Set 8 | chimbote
# Processing Record 46 of Set 8 | panguna
# Processing Record 47 of Set 8 | itoman
# Processing Record 48 of Set 8 | honningsvag
# Processing Record 49 of Set 8 | faanui
# Processing Record 50 of Set 8 | bathsheba
# Processing Record 1 of Set 9 | panaba
# Processing Record 2 of Set 9 | mount holly
# Processing Record 3 of Set 9 | chirongui
# Processing Record 4 of Set 9 | fuyu
# Processing Record 5 of Set 9 | urubicha
# Processing Record 6 of Set 9 | culpeper
# Processing Record 7 of Set 9 | kouroussa
# Processing Record 8 of Set 9 | poum
# Processing Record 9 of Set 9 | kontagora
# Processing Record 10 of Set 9 | erenhot
# Processing Record 11 of Set 9 | oktyabrskoye
# Processing Record 12 of Set 9 | enshi
# Processing Record 13 of Set 9 | gawler
# Processing Record 14 of Set 9 | te anau
# Processing Record 15 of Set 9 | vila
# Processing Record 16 of Set 9 | getulio vargas
# Processing Record 17 of Set 9 | lavumisa
# Processing Record 18 of Set 9 | doha
# Processing Record 19 of Set 9 | chengannur
# Processing Record 20 of Set 9 | locharbriggs
# Processing Record 21 of Set 9 | ostroleka
# Processing Record 22 of Set 9 | puerto ayacucho
# Processing Record 23 of Set 9 | northam
# Processing Record 24 of Set 9 | kawalu
# Processing Record 25 of Set 9 | khonuu
# City not found. Skipping
# Processing Record 26 of Set 9 | lagoa
# Processing Record 27 of Set 9 | douglas
# Processing Record 28 of Set 9 | skjervoy
# Processing Record 29 of Set 9 | zaoyang
# Processing Record 30 of Set 9 | basco
# Processing Record 31 of Set 9 | port hawkesbury
# Processing Record 32 of Set 9 | hamilton
# Processing Record 33 of Set 9 | ginir
# Processing Record 34 of Set 9 | blagoyevo
# Processing Record 35 of Set 9 | leningradskiy
# Processing Record 36 of Set 9 | wajir
# Processing Record 37 of Set 9 | katiola
# Processing Record 38 of Set 9 | beloha
# Processing Record 39 of Set 9 | japura
# Processing Record 40 of Set 9 | camopi
# Processing Record 41 of Set 9 | asosa
# Processing Record 42 of Set 9 | benguela
# Processing Record 43 of Set 9 | khandbari
# Processing Record 44 of Set 9 | cravo norte
# Processing Record 45 of Set 9 | tiarei
# Processing Record 46 of Set 9 | huarmey
# Processing Record 47 of Set 9 | abalak
# Processing Record 48 of Set 9 | teguldet
# Processing Record 49 of Set 9 | rio grande
# Processing Record 50 of Set 9 | compostela
# Processing Record 1 of Set 10 | cabo san lucas
# Processing Record 2 of Set 10 | fukue
# Processing Record 3 of Set 10 | xiongzhou
# Processing Record 4 of Set 10 | gorno-chuyskiy
# City not found. Skipping
# Processing Record 5 of Set 10 | zhuhai
# Processing Record 6 of Set 10 | roald
# Processing Record 7 of Set 10 | nhulunbuy
# Processing Record 8 of Set 10 | srednekolymsk
# Processing Record 9 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping
# Processing Record 10 of Set 10 | riyadh
# Processing Record 11 of Set 10 | arlit
# Processing Record 12 of Set 10 | kenai
# Processing Record 13 of Set 10 | abashiri
# Processing Record 14 of Set 10 | kieta
# Processing Record 15 of Set 10 | podgorenskiy
# Processing Record 16 of Set 10 | asbe teferi
# Processing Record 17 of Set 10 | kapuskasing
# Processing Record 18 of Set 10 | mount gambier
# Processing Record 19 of Set 10 | ngaoundere
# Processing Record 20 of Set 10 | tiznit
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | kuryk
# Processing Record 23 of Set 10 | foshan
# Processing Record 24 of Set 10 | bogalusa
# Processing Record 25 of Set 10 | buariki
# City not found. Skipping
# Processing Record 26 of Set 10 | talaya
# Processing Record 27 of Set 10 | sajanan
# Processing Record 28 of Set 10 | kokstad
# Processing Record 29 of Set 10 | aberdeen
# Processing Record 30 of Set 10 | zolotinka
# City not found. Skipping
# Processing Record 31 of Set 10 | el alto
# Processing Record 32 of Set 10 | san patricio
# Processing Record 33 of Set 10 | tezu
# Processing Record 34 of Set 10 | talakan
# Processing Record 35 of Set 10 | zhigansk
# Processing Record 36 of Set 10 | tabiauea
# City not found. Skipping
# Processing Record 37 of Set 10 | goderich
# Processing Record 38 of Set 10 | zmiyiv
# Processing Record 39 of Set 10 | constitucion
# Processing Record 40 of Set 10 | general roca
# Processing Record 41 of Set 10 | los llanos de aridane
# Processing Record 42 of Set 10 | kamenskoye
# City not found. Skipping
# Processing Record 43 of Set 10 | las tunas
# Processing Record 44 of Set 10 | haapu
# City not found. Skipping
# Processing Record 45 of Set 10 | virden
# Processing Record 46 of Set 10 | kayerkan
# Processing Record 47 of Set 10 | dujuma
# City not found. Skipping
# Processing Record 48 of Set 10 | oussouye
# Processing Record 49 of Set 10 | zhangjiakou
# Processing Record 50 of Set 10 | ifakara
# Processing Record 1 of Set 11 | tessalit
# Processing Record 2 of Set 11 | ogembo
# Processing Record 3 of Set 11 | marmaris
# Processing Record 4 of Set 11 | norton
# Processing Record 5 of Set 11 | baykit
# Processing Record 6 of Set 11 | necochea
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | abay
# Processing Record 9 of Set 11 | zhuanghe
# Processing Record 10 of Set 11 | awjilah
# Processing Record 11 of Set 11 | ust-kamchatsk
# City not found. Skipping
# Processing Record 12 of Set 11 | saint anthony
# Processing Record 13 of Set 11 | kurya
# Processing Record 14 of Set 11 | culebra
# Processing Record 15 of Set 11 | sorong
# Processing Record 16 of Set 11 | ovalle
# Processing Record 17 of Set 11 | jaypur
# Processing Record 18 of Set 11 | miranda
# Processing Record 19 of Set 11 | aras
# Processing Record 20 of Set 11 | mullaitivu
# City not found. Skipping
# Processing Record 21 of Set 11 | bacolod
# Processing Record 22 of Set 11 | fort nelson
# Processing Record 23 of Set 11 | borovichi
# Processing Record 24 of Set 11 | marsa matruh
# Processing Record 25 of Set 11 | richards bay
# Processing Record 26 of Set 11 | camana
# Processing Record 27 of Set 11 | saquena
# Processing Record 28 of Set 11 | seabra
# Processing Record 29 of Set 11 | quelimane
# Processing Record 30 of Set 11 | busia
# Processing Record 31 of Set 11 | verkhnevilyuysk
# Processing Record 32 of Set 11 | polunochnoye
# Processing Record 33 of Set 11 | teguise
# Processing Record 34 of Set 11 | colac
# Processing Record 35 of Set 11 | hasaki
# Processing Record 36 of Set 11 | yulara
# Processing Record 37 of Set 11 | innisfail
# Processing Record 38 of Set 11 | noumea
# Processing Record 39 of Set 11 | sao borja
# Processing Record 40 of Set 11 | bestobe
# Processing Record 41 of Set 11 | taltal
# Processing Record 42 of Set 11 | moron
# Processing Record 43 of Set 11 | plouzane
# Processing Record 44 of Set 11 | manaia
# Processing Record 45 of Set 11 | mama
# Processing Record 46 of Set 11 | gotsu
# Processing Record 47 of Set 11 | belinskiy
# Processing Record 48 of Set 11 | montrose
# Processing Record 49 of Set 11 | praia da vitoria
# Processing Record 50 of Set 11 | bargal
# City not found. Skipping
# Processing Record 1 of Set 12 | alyangula
# Processing Record 2 of Set 12 | anadyr
# Processing Record 3 of Set 12 | tanggul
# Processing Record 4 of Set 12 | mahanoro
# Processing Record 5 of Set 12 | eravur
# Processing Record 6 of Set 12 | sarangani
# Processing Record 7 of Set 12 | nokaneng
# Processing Record 8 of Set 12 | fergus falls
# Processing Record 9 of Set 12 | jiuquan
# Processing Record 10 of Set 12 | minudasht
# Processing Record 11 of Set 12 | bayir
# Processing Record 12 of Set 12 | qurayyat
# Processing Record 13 of Set 12 | gweta
# Processing Record 14 of Set 12 | ocos
# Processing Record 15 of Set 12 | bima
# Processing Record 16 of Set 12 | sept-iles
# Processing Record 17 of Set 12 | presidencia roque saenz pena
# Processing Record 18 of Set 12 | the valley
# Processing Record 19 of Set 12 | lompoc
# Processing Record 20 of Set 12 | luderitz
# Processing Record 21 of Set 12 | dubno
# Processing Record 22 of Set 12 | weinan
# Processing Record 23 of Set 12 | gao
# Processing Record 24 of Set 12 | meulaboh
# Processing Record 25 of Set 12 | dinar
# Processing Record 26 of Set 12 | acarau
# Processing Record 27 of Set 12 | angoche
# Processing Record 28 of Set 12 | lac du bonnet
# Processing Record 29 of Set 12 | sao gabriel da cachoeira
# Processing Record 30 of Set 12 | pachino
# Processing Record 31 of Set 12 | imuris
# Processing Record 32 of Set 12 | lakefield
# Processing Record 33 of Set 12 | bac lieu
# Processing Record 34 of Set 12 | puerto vallarta
# Processing Record 35 of Set 12 | new castle
# Processing Record 36 of Set 12 | bismil
# Processing Record 37 of Set 12 | ystad
# Processing Record 38 of Set 12 | yanchukan
# City not found. Skipping
# Processing Record 39 of Set 12 | ayan
# Processing Record 40 of Set 12 | nishihara
# Processing Record 41 of Set 12 | hay river
# Processing Record 42 of Set 12 | khartoum
# Processing Record 43 of Set 12 | soe
# Processing Record 44 of Set 12 | kadykchan
# City not found. Skipping
# Processing Record 45 of Set 12 | havelock
# Processing Record 46 of Set 12 | walvis bay
# Processing Record 47 of Set 12 | mae ramat
# Processing Record 48 of Set 12 | sioux lookout
# Processing Record 49 of Set 12 | kuche
# City not found. Skipping
# Processing Record 50 of Set 12 | san jeronimo
# Processing Record 1 of Set 13 | shetpe
# Processing Record 2 of Set 13 | fasa
# Processing Record 3 of Set 13 | novoagansk
# Processing Record 4 of Set 13 | stromness
# Processing Record 5 of Set 13 | aykhal
# Processing Record 6 of Set 13 | khandyga
# Processing Record 7 of Set 13 | aswan
# Processing Record 8 of Set 13 | puerto escondido
# Processing Record 9 of Set 13 | dwarka
# Processing Record 10 of Set 13 | samarai
# Processing Record 11 of Set 13 | springdale
# Processing Record 12 of Set 13 | gwalior
# Processing Record 13 of Set 13 | saint-joseph
# Processing Record 14 of Set 13 | beringovskiy
# Processing Record 15 of Set 13 | pasighat
# Processing Record 16 of Set 13 | san cristobal
# Processing Record 17 of Set 13 | mackay
# Processing Record 18 of Set 13 | zambezi
# Processing Record 19 of Set 13 | atherton
# Processing Record 20 of Set 13 | matasari
# Processing Record 21 of Set 13 | laguna
# Processing Record 22 of Set 13 | murray bridge
# Processing Record 23 of Set 13 | sfantu gheorghe
# Processing Record 24 of Set 13 | haapiti
# Processing Record 25 of Set 13 | tubruq
# City not found. Skipping
# Processing Record 26 of Set 13 | college
# Processing Record 27 of Set 13 | babushkin
# Processing Record 28 of Set 13 | ponta delgada
# Processing Record 29 of Set 13 | westport
# Processing Record 30 of Set 13 | eureka
# Processing Record 31 of Set 13 | senno
# Processing Record 32 of Set 13 | kushiro
# Processing Record 33 of Set 13 | salalah
# Processing Record 34 of Set 13 | medea
# Processing Record 35 of Set 13 | san carlos de bariloche
# Processing Record 36 of Set 13 | sakakah
# Processing Record 37 of Set 13 | itarema
# Processing Record 38 of Set 13 | plettenberg bay
# Processing Record 39 of Set 13 | tanda
# Processing Record 40 of Set 13 | tecoanapa
# Processing Record 41 of Set 13 | veinticinco de mayo
# Processing Record 42 of Set 13 | linhares
# Processing Record 43 of Set 13 | florenville
# Processing Record 44 of Set 13 | tres lagoas
# Processing Record 45 of Set 13 | powell river
# Processing Record 46 of Set 13 | bourail
# Processing Record 47 of Set 13 | estelle
# Processing Record 48 of Set 13 | ambilobe
# Processing Record 49 of Set 13 | atar
# Processing Record 50 of Set 13 | tall kayf
# Processing Record 1 of Set 14 | mzimba
# Processing Record 2 of Set 14 | morros
# Processing Record 3 of Set 14 | natal
# Processing Record 4 of Set 14 | lethem
# Processing Record 5 of Set 14 | charyshskoye
# Processing Record 6 of Set 14 | nelson bay
# Processing Record 7 of Set 14 | zaysan
# Processing Record 8 of Set 14 | sur
# Processing Record 9 of Set 14 | pangnirtung
# Processing Record 10 of Set 14 | sorsk
# Processing Record 11 of Set 14 | olinda
# Processing Record 12 of Set 14 | jumla
# Processing Record 13 of Set 14 | harper
# Processing Record 14 of Set 14 | port hueneme
# Processing Record 15 of Set 14 | charlestown
# Processing Record 16 of Set 14 | clyde river
# Processing Record 17 of Set 14 | tibacuy
# Processing Record 18 of Set 14 | utiroa
# City not found. Skipping
# Processing Record 19 of Set 14 | inirida
# Processing Record 20 of Set 14 | umzimvubu
# City not found. Skipping
# Processing Record 21 of Set 14 | emerald
# Processing Record 22 of Set 14 | vieux-habitants
# Processing Record 23 of Set 14 | mildura
# Processing Record 24 of Set 14 | we
# City not found. Skipping
# Processing Record 25 of Set 14 | yendi
# Processing Record 26 of Set 14 | ulladulla
# Processing Record 27 of Set 14 | kedougou
# Processing Record 28 of Set 14 | teyateyaneng
# Processing Record 29 of Set 14 | midland
# Processing Record 30 of Set 14 | diego de almagro
# Processing Record 31 of Set 14 | virginia beach
# Processing Record 32 of Set 14 | nkhata bay
# Processing Record 33 of Set 14 | neverkino
# Processing Record 34 of Set 14 | mega
# Processing Record 35 of Set 14 | dong hoi
# Processing Record 36 of Set 14 | wa
# City not found. Skipping
# Processing Record 37 of Set 14 | tuensang
# Processing Record 38 of Set 14 | bialystok
# Processing Record 39 of Set 14 | ahar
# Processing Record 40 of Set 14 | magnitka
# Processing Record 41 of Set 14 | vaitape
# Processing Record 42 of Set 14 | mananara
# Processing Record 43 of Set 14 | mombasa
# Processing Record 44 of Set 14 | tumannyy
# City not found. Skipping
# Processing Record 45 of Set 14 | bur gabo
# City not found. Skipping
# Processing Record 46 of Set 14 | clovis
# Processing Record 47 of Set 14 | elkridge
# Processing Record 48 of Set 14 | mount vernon
# Processing Record 49 of Set 14 | vakhrushev
# Processing Record 50 of Set 14 | sipovo
# Processing Record 1 of Set 15 | kudahuvadhoo
# Processing Record 2 of Set 15 | toktogul
# Processing Record 3 of Set 15 | manggar
# Processing Record 4 of Set 15 | vao
# Processing Record 5 of Set 15 | phangnga
# Processing Record 6 of Set 15 | huazolotitlan
# City not found. Skipping
# Processing Record 7 of Set 15 | cabaiguan
# Processing Record 8 of Set 15 | trelew
# Processing Record 9 of Set 15 | talawdi
# City not found. Skipping
# Processing Record 10 of Set 15 | goure
# Processing Record 11 of Set 15 | la ronge
# Processing Record 12 of Set 15 | dalvik
# Processing Record 13 of Set 15 | kem
# Processing Record 14 of Set 15 | kamarion
# Processing Record 15 of Set 15 | coihaique
# Processing Record 16 of Set 15 | aguimes
# Processing Record 17 of Set 15 | sao sebastiao
# Processing Record 18 of Set 15 | newton
# Processing Record 19 of Set 15 | gambela
# Processing Record 20 of Set 15 | marawi
# Processing Record 21 of Set 15 | buala
# Processing Record 22 of Set 15 | santa rosa
# Processing Record 23 of Set 15 | poninka
# Processing Record 24 of Set 15 | cockburn town
# Processing Record 25 of Set 15 | erzin
# Processing Record 26 of Set 15 | petatlan
# Processing Record 27 of Set 15 | bend
# Processing Record 28 of Set 15 | isangel
# Processing Record 29 of Set 15 | sulangan
# Processing Record 30 of Set 15 | surenavan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 674

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Aklavik      CA  2022-04-10 13:43:47  68.2191 -135.0107    -17.12
# 1       Rikitea      PF  2022-04-10 13:39:28 -23.1203 -134.9692     78.62
# 2  Presque Isle      US  2022-04-10 13:43:47  46.6811  -68.0159     41.18
# 3     Jamestown      US  2022-04-10 13:43:47  42.0970  -79.2353     35.19
# 4        Manaus      BR  2022-04-10 13:43:48  -3.1019  -60.0250     82.89
# 5         Vaini      TO  2022-04-10 13:41:10 -21.2000 -175.2000     77.16
# 6         Bluff      NZ  2022-04-10 13:40:59 -46.6000  168.3333     49.21
# 7     Carnarvon      AU  2022-04-10 13:43:48 -24.8667  113.6333     71.67
# 8        Kashin      RU  2022-04-10 13:43:49  57.3592   37.6081     49.93
# 9  Kruisfontein      ZA  2022-04-10 13:43:49 -34.0033   24.7314     67.89
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        98          85        2.33     overcast clouds
# 1        73           1       15.68           clear sky
# 2       100         100        0.00                mist
# 3        52         100       14.97     overcast clouds
# 4        78          40        2.30    scattered clouds
# 5        94          40        5.75    scattered clouds
# 6        88          31        8.12    scattered clouds
# 7        68           0       17.27           clear sky
# 8        58         100        6.42     overcast clouds
# 9        74          95       17.83          light rain

# %%
# Create CSV file of DF
csv_weather_file = "weather_database/weather_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
